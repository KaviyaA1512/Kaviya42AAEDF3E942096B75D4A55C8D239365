# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/atm_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balance = 1000

while True:
    print("\n1.Deposit 2.Withdraw 3.Balance 4.Exit")
    ch = int(input("Enter choice: "))


    if ch == 1:

            amount = int(input("Enter amount: "))
            if amount > 0:
                balance += amount
                print("Amount Deposited")

    elif ch == 2:

            amount = int(input("Enter amount: "))
            if amount > 0:
                if amount <= balance:
                    balance -= amount
                    print("Amount Withdrawn")
                else:
                    print("Insufficient Balance")

    elif ch == 3:
        print("Balance:", balance)

    elif ch == 4:
        print("Exiting program.")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# 1.Deposit 2.Withdraw 3.Balance 4.Exit
# Enter choice: 1
# Enter amount: 1000
# Amount Deposited
#
# 1.Deposit 2.Withdraw 3.Balance 4.Exit
# Enter choice: 2
# Enter amount: 100
# Amount Withdrawn
#
# 1.Deposit 2.Withdraw 3.Balance 4.Exit
# Enter choice: 3
# Balance: 1900
#
# 1.Deposit 2.Withdraw 3.Balance 4.Exit
# Enter choice: 4
# Exiting program.

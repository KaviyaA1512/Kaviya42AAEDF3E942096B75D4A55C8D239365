# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/run_until_0_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("to stop the program enter 0")
while True:
    a=int(input("enter a number:"))

    if(a==0):
      break

print("Program will be excecuted until 0")
print(" loop completed")
# Out:
# to stop the program enter 0
# enter a number:8
# enter a number:9
# enter a number:7
# enter a number:6
# enter a number:0
# Program will be excecuted until 0
#  loop completed

# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/string().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="Advanced Python"
print("---positive indexing---")
print("5 th position:",s[5])
print("inbetween 2 and 7:",s[2:7])

print("---negative indexing---")
print("5 th position negative",s[-5])
print("inbetween -7 and -2",s[-7:-2])

print("---slicing---")
print("before 5 :",s[:5])#before 5
print("after 5:",s[5:])#after 5
print("inbetween4 & 10 ",s[4:10])
print("inbetween negative -10 & -4:",s[-10:-4])

print("---ocuurance---")
print("occurance of a :",s.count("a"))
print("occurance of n :",s.count("n"))

print("---replace---")
print("replace:d",s.replace("python","language"))
# Out:
# ---positive indexing---
# 5 th position: c
# inbetween 2 and 7: vance
# ---negative indexing---
# 5 th position negative y
# inbetween -7 and -2  Pyth
# ---slicing---
# before 5 : Advan
# after 5: ced Python
# inbetween4 & 10  nced P
# inbetween negative -10 & -4: ced Py
# ---ocuurance---
# occurance of a : 1
# occurance of n : 2
# ---replace---
# replace:d Advanced Python

# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/1toN_and_sum_of_N_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter a number:"))
sum=0
print("---1 to N numbers-----")
for i in range(1,n+1):
    print(i)
    sum+=i


print("----Sum of N numbers---")
print("sum :",sum)
# Out:
# Enter a number:4
# ---1 to N numbers-----
# 1
# 2
# 3
# 4
# ----Sum of N numbers---
# sum : 10

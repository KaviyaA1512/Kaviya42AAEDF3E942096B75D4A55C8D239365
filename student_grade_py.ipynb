# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/student_grade_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input("Enter a name:")
b=int(input("Enter register no:"))
n=int(input("Enter the no.subjects:"))
total=0
for i in range(1,n+1):
    c=input("Enter subject name:")
    mark=int(input("Enter the marks: "))
    total+=mark
    average=total/n
    if(average>=90):
        grade="A+"
    elif(average>=75):
        grade="A"
    elif(average>=60):
        grade="B"
    elif(average>=50):
        grade="C"
    else:
        grade="Fail"
print("------RESULT--------")
print("Name =",a)
print("Register no =",b)
print("Total =",total)
print("Average =",average)
print("--------------------")
# Out:
# ENter a name:kaviya
# Enter register no:6052181
# Enter the no.subjects:6
# Enter subject name:advanced python
# Enter the marks: 98
# Enter subject name:data structure
# Enter the marks: 95
# Enter subject name:info security
# Enter the marks: 96
# Enter subject name:web application
# Enter the marks: 90
# Enter subject name:e commerce
# Enter the marks: 92
# Enter subject name:maths
# Enter the marks: 90
# ------RESULT--------
# Name = kaviya
# Register no = 6052181
# Total = 561
# Average = 93.5
# --------------------

# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/number_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter a decimal number inbetween 10-16:"))
print("Decimal to binary:",bin(n)[2:])
print("Decimal to octal:",oct(n)[2:])
print("Decimal to hexadecimal:",hex(n)[2:].upper())
# Out:
# Enter a decimal number greater than 10:14
# Decimal to binary: 1110
# Decimal to octal: 16
# Decimal to hexadecimal: E

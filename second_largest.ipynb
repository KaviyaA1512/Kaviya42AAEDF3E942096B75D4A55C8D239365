# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/second_largest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = []
n = int(input("Enter the number of elements: "))
for i in range(n):
    numbers.append(int(input("Enter a number: ")))

numbers.sort()

print("Second Largest Number:", numbers[-2])
# Out:
# Enter the number of elements: 3
# Enter a number: 10
# Enter a number: 9
# Enter a number: 5
# Second Largest Number: 9

# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/6lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
simple calculation

# %%
a=int(input("Enter value 1:"))
b=int(input("Enter value 2:"))
print("Addition:",a+b)
print("subtraction:",a-b)
print("multiply:",a*b)
print("remainder:",a%b)
print("power:",a**b)
# Out:
# Enter value 1:2
# Enter value 2:4
# Addition: 6
# subtraction: -2
# multiply: 8
# remainder: 2
# power: 16

# %%
find length,reverse and concate 2 strings

# %%
s="Adavanced"
a="python"
print("length:",len(s))
print("concate:",s+a)
print("Reverse:",s[::-1])
# Out:
# length: 9
# concate: Adavancedpython
# Reverse: decnavadA

# %%
assign grades for students

# %%
a=input("ENter a name:")
b=int(input("Enter register no:"))
n=int(input("Enter the no.subjects:"))
total=0
for i in range(1,n+1):
    c=input("Enter subject name:")
    mark=int(input("Enter the marks: "))
    total+=mark
    average=total/n
    if(average>=90):
        grade="A+"
    elif(average>=75):
        grade="A"
    elif(average>=60):
        grade="B"
    elif(average>=50):
        grade="C"
    else:
        grade="Fail"
print("------RESULT--------")
print("Name =",a)
print("Register no =",b)
print("Total =",total)
print("Average =",average)
print("--------------------")
# Out:
# ENter a name:kaviya
# Enter register no:6052181
# Enter the no.subjects:6
# Enter subject name:python
# Enter the marks: 98
# Enter subject name:data structure
# Enter the marks: 95
# Enter subject name:info security
# Enter the marks: 90
# Enter subject name:web application
# Enter the marks: 90
# Enter subject name:e commerce
# Enter the marks: 98
# Enter subject name:maths
# Enter the marks: 90
# ------RESULT--------
# Name = kaviya
# Register no = 6052181
# Total = 561
# Average = 93.5
# --------------------

# %%
print 1 to N and sum of N numbers

# %%
n=int(input("Enter a number:"))
sum=0
print("---1 to N numbers-----")
for i in range(1,n+1):
    print(i)
    sum+=i


print("----Sum of N numbers---")
print("sum :",sum)
# Out:
# Enter a number:5
# ---1 to N numbers-----
# 1
# 2
# 3
# 4
# 5
# ----Sum of N numbers---
# sum : 15

# %%
repeatedly accept numbers until 0

# %%
while True:
    a=int(input("enter a number(enter 0 to stop):"))

    if(a==0):
      break

print("Program will be excecuted until 0")
print(" loop completed")
# Out:
# enter a number(enter 0 to stop):9
# enter a number(enter 0 to stop):7
# enter a number(enter 0 to stop):9
# enter a number(enter 0 to stop):5
# enter a number(enter 0 to stop):0
# Program will be excecuted until 0
#  loop completed

# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/simplecal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("Enter value 1:"))
b=int(input("Enter value 2:"))
print("Addition:",a+b)
print("subtraction:",a-b)
print("multiply:",a*b)
print("remainder:",a%b)
print("power:",a**b)
# Out:
# Enter value 1:2
# Enter value 2:4
# Addition: 6
# subtraction: -2
# multiply: 8
# remainder: 2
# power: 16

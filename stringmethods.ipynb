# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/stringmethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s=input("Enter a String:")
d=input("Enter string 2:")
print("Change the String into upper case:",s.upper())
print("change the string into lower case:",s.lower())
print("Strip the string:",s.strip())
print("splitted string:",s.split())
print("Titled string:",s.title())
print("Capitalize the string:",s.capitalize())
print("joined string :", " and ".join([s, d]))
# Out:
# Enter a String:A cat is sitting on a ball
# Enter string 2:looking at a ball
# Change the String into upper case: A CAT IS SITTING ON A BALL
# change the string into lower case: a cat is sitting on a ball
# Strip the string: A cat is sitting on a ball
# splitted string: ['A', 'cat', 'is', 'sitting', 'on', 'a', 'ball']
# Titled string: A Cat Is Sitting On A Ball
# Capitalize the string: A cat is sitting on a ball
# joined string : A cat is sitting on a ball and looking at a ball

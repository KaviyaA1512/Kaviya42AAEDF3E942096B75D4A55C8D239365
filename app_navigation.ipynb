# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/app_navigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
screens = []

screens.append("Home")
screens.append("Profile")
screens.append("Settings")

print("Current Screen:", screens[-1])

print("Back from:", screens.pop())

print("Current Screen:", screens[-1])
# Out:
# Current Screen: Settings
# Back from: Settings
# Current Screen: Profile

# %% [markdown]
# <a href="https://colab.research.google.com/github/KaviyaA1512/Kaviya42AAEDF3E942096B75D4A55C8D239365/blob/main/min_max_duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list=[60,89,90,56,74,80,60]
list2=[90,80,70]
list3=list+list2
print("original list:",list)
print("largest no:",max(list))
print("smallest no:",min(list))
print("after duplicates removed:",set(list))
print("merged list:",list3)
# Out:
# original list: [60, 89, 90, 56, 74, 80, 60]
# largest no: 90
# smallest no: 56
# after duplicates removed: {74, 80, 56, 89, 90, 60}
# merged list: [60, 89, 90, 56, 74, 80, 60, 90, 80, 70]
